# %%
from pathlib import Path
import pandas as pd

raw = Path("../data/raw")

for file in raw.glob("*.xlsx"):
    df = pd.read_excel(file)

    print("="*70)
    print(file.name)
    print(df.shape)
    print(df.columns.tolist())
# Out:
# ...
# analysis.xlsx
# (21, 6)
# ['Bluestock Fintech — Nifty 100  |  Analysis  |  20 records', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5']
# ...
# balancesheet.xlsx
# (1313, 13)
# ['Bluestock Fintech — Nifty 100  |  Balance Sheet  |  1,312 records', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12']
# ...
# cashflow.xlsx
# (1188, 7)
# ['Bluestock Fintech — Nifty 100  |  Cash Flow  |  1,187 records', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6']
# ...
# companies.xlsx
# (93, 12)
# ['Mkt Fintech — Nifty 100  |  Companies  |  92 records', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11']
# ...
# documents.xlsx
# (1586, 4)
# ['Bluestock Fintech — Nifty 100  |  Documents  |  1,585 records', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3']
# ...

# %%
import pandas as pd

files = [
    "companies.xlsx",
    "profitandloss.xlsx",
    "balancesheet.xlsx",
    "cashflow.xlsx",
    "analysis.xlsx",
    "documents.xlsx",
    "prosandcons.xlsx"
]

for file in files:

    print("\n" + "="*80)
    print(file)

    df = pd.read_excel(
        f"../data/raw/{file}",
        header=None
    )

    print(df.head(10))
# Out:
# ...
# companies.xlsx
#                                                   0   \
# 0  Mkt Fintech — Nifty 100  |  Companies  |  92 r...
# 1                                                 id
# 2                                                ABB
# 3                                         ADANIENSOL
# 4                                           ADANIENT
# 5                                         ADANIGREEN
# 6                                         ADANIPORTS
# 7                                         ADANIPOWER
# 8                                          AMBUJACEM
# 9                                         APOLLOHOSP
#
#                                                   1   \
# 0                                                NaN
# 1                                       company_logo
# 2   https://mkt.in/static/mkt-icons/nifty100/ABB.png
# 3  https://m.economictimes.com/thumb/msid-1173715...
# 4  https://mkt.in/static/mkt-icons/nifty100/ADANI...
# ...
